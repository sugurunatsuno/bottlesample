# %%
import sqlite3

# %%
connection = sqlite3.connect('./test.db')

# %%
cur = connection.cursor()

# %%
cur.execute("create table phrase (id real, ja text, other text)")

# %%
cur.execute("insert into phrase values (1, '私は今日、大学に行った。', 'I went to my university today.')")

# %%
connection.commit()

# %%
connection.close()

# %%
connection = sqlite3.connect('./test.db')

# %%
cur = connection.cursor()

# %%
for row in cur.execute('select * from phrase'):
    print(row)
# Out:
# (1.0, '私は今日、大学に行った。', 'I went to my university today.')
